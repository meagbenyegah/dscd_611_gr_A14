# %%
# Import required libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import SelectKBest, f_classif
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Load Cleaned Data
# Load the data after initial cleaning.

# %%
# Load processed data
# data = pd.read_csv('../data/processed/cleaned_data.csv')
# data.head()

# %% [markdown]
# ## 2. Handle Missing Values
# Impute or remove missing values based on strategy.

# %%
# Handle missing values
# # Option 1: Fill with median for numerical columns
# # data.fillna(data.median(), inplace=True)
# 
# # Option 2: Fill with mode for categorical columns
# # for col in data.select_dtypes(include='object').columns:
# #     data[col].fillna(data[col].mode()[0], inplace=True)

# %% [markdown]
# ## 3. Encode Categorical Variables
# Convert categorical features to numerical format.

# %%
# Encode categorical variables
# categorical_cols = data.select_dtypes(include='object').columns
# 
# for col in categorical_cols:
#     if col != 'disease':  # Don't encode target variable yet
#         le = LabelEncoder()
#         data[col] = le.fit_transform(data[col])

# %% [markdown]
# ## 4. Feature Scaling
# Scale numerical features for better model performance.

# %%
# Scale features
# scaler = StandardScaler()
# feature_cols = [col for col in data.columns if col != 'disease']
# 
# data_scaled = data.copy()
# data_scaled[feature_cols] = scaler.fit_transform(data[feature_cols])

# %% [markdown]
# ## 5. Feature Selection
# Select the most important features using statistical tests.

# %%
# Feature selection
# X = data_scaled.drop('disease', axis=1)
# y = data_scaled['disease']
# 
# selector = SelectKBest(f_classif, k=10)
# X_selected = selector.fit_transform(X, y)
# 
# # Get selected feature names
# selected_features = X.columns[selector.get_support()].tolist()
# print("Selected features:", selected_features)

# %% [markdown]
# ## 6. Save Processed Data
# Save the engineered features for model training.

# %%
# Save processed data
# data_scaled.to_csv('../data/processed/features_engineered.csv', index=False)
# print("Processed data saved successfully!")
