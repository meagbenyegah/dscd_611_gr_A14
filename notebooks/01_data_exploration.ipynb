# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set plotting style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## 1. Load Data
# Load the raw patient symptom data from the data/raw folder.

# %%
# Load data
# data = pd.read_csv('../data/raw/patient_symptoms.csv')
# data.head()

# %% [markdown]
# ## 2. Data Overview
# Check the shape, data types, and basic statistics.

# %%
# Display dataset info
# print(f"Dataset shape: {data.shape}")
# print("\nData types:")
# print(data.dtypes)
# print("\nBasic statistics:")
# data.describe()

# %% [markdown]
# ## 3. Missing Values Analysis
# Identify and visualize missing values in the dataset.

# %%
# Check for missing values
# missing = data.isnull().sum()
# missing_pct = (missing / len(data)) * 100
# 
# plt.figure(figsize=(12, 6))
# missing_pct[missing_pct > 0].plot(kind='bar')
# plt.title('Missing Values by Feature (%)')
# plt.ylabel('Percentage')
# plt.show()

# %% [markdown]
# ## 4. Target Variable Distribution
# Analyze the distribution of disease diagnoses.

# %%
# Plot target distribution
# disease_counts = data['disease'].value_counts()
# 
# plt.figure(figsize=(10, 6))
# disease_counts.plot(kind='bar')
# plt.title('Disease Distribution')
# plt.xlabel('Disease')
# plt.ylabel('Count')
# plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 5. Feature Correlation Analysis
# Examine correlations between symptoms.

# %%
# Correlation heatmap
# plt.figure(figsize=(12, 10))
# correlation = data.corr()
# sns.heatmap(correlation, cmap='coolwarm', center=0, annot=False)
# plt.title('Feature Correlation Matrix')
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## Next Steps
# - Clean and preprocess data
# - Engineer new features
# - Prepare data for modeling
